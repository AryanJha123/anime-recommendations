# %%
import requests
import json

# %%
# Here we define our query as a multi-line string
query = '''
query{ # Define which variables will be used in the query (id)
  Page(page: 10){
  media (type: ANIME sort:START_DATE duration_greater:0) {
    id
    title {
      romaji
    }
  }
  }
}
'''

url = 'https://graphql.anilist.co'

# Make the HTTP Api request
response = requests.post(url, json={'query': query})

# %%
response.content
# Out:
# b'{"data":{"Page":{"media":[{"id":3294,"title":{"romaji":"Gasshin Sentai Mechander Robo"}},{"id":1986,"title":{"romaji":"Wakusei Robo Danguard Ace"}},{"id":9279,"title":{"romaji":"Bara no Hana to Joe"}},{"id":3847,"title":{"romaji":"Sekai Meisaku Douwa: Hakuchou no Ouji"}},{"id":176882,"title":{"romaji":"Sora ni wa Otsuki-sama"}},{"id":4339,"title":{"romaji":"Ashita e Attack!"}},{"id":8375,"title":{"romaji":"Chogattai Majutsu Robot Ginguiser"}},{"id":9781,"title":{"romaji":"Hyouga Senshi Gaislugger"}},{"id":19959,"title":{"romaji":"Barbapapa (1977)"}},{"id":169094,"title":{"romaji":"Tenshi no Pants"}},{"id":140229,"title":{"romaji":"Ichigo no Hanayome-san"}},{"id":1069,"title":{"romaji":"Chou Denji Machine Voltes V"}},{"id":4514,"title":{"romaji":"Seton Doubutsuki: Kuma no Ko Jacky"}},{"id":145281,"title":{"romaji":"Watashi wa \\"Tofu\\" Desu"}},{"id":6970,"title":{"romaji":"Choujin Sentai Baratack"}},{"id":8707,"title":{"romaji":"Wakusei Robo Danguard Ace tai Konchuu Robot Gundan"}},{"id":16566,"title":{"romaji":"Robot Taekwon V 3tan! Sujung Teukgongdae"}},{"id":14821,"title":{"romaji":"Taekwon Dongja Maruchi Arachi"}},{"id":145906,"title":{"romaji":"Salamandra"}},{"id":711,"title":{"romaji":"Uchuu Senkan Yamato (Movie)"}},{"id":7771,"title":{"romaji":"Chiisana Jumbo"}},{"id":3827,"title":{"romaji":"Ore wa Teppei"}},{"id":5287,"title":{"romaji":"Ippatsu Kanta-kun"}},{"id":3800,"title":{"romaji":"Arrow Emblem: Grand Prix no Taka"}},{"id":139101,"title":{"romaji":"Ponta Monogatari"}},{"id":2809,"title":{"romaji":"Fuusen Shoujo Temple-chan"}},{"id":15875,"title":{"romaji":"Shin Kyojin no Hoshi"}},{"id":2828,"title":{"romaji":"Ie Naki Ko"}},{"id":1425,"title":{"romaji":"Lupin III: Part II"}},{"id":9881,"title":{"romaji":"Chou Supercar Gattiger"}},{"id":9856,"title":{"romaji":"Manga Nihon Emaki"}},{"id":20125,"title":{"romaji":"Tobidase! Machine Hiryuu"}},{"id":169054,"title":{"romaji":"Aki Monogatari"}},{"id":4073,"title":{"romaji":"Kyouryuu Daisensou Aizenborg"}},{"id":173265,"title":{"romaji":"Sora to Umi no Komoriuta"}},{"id":2200,"title":{"romaji":"Muteki Choujin Zambot 3"}},{"id":20115,"title":{"romaji":"Gekisou! Rubenkaiser"}},{"id":3196,"title":{"romaji":"Wakakusa no Charlotte"}},{"id":20183,"title":{"romaji":"Manga Ijin Monogatari"}},{"id":139098,"title":{"romaji":"Akaoni to Aooni no Tango"}},{"id":114942,"title":{"romaji":"Soumatou"}},{"id":16399,"title":{"romaji":"Jeonja Ingan 337"}},{"id":3435,"title":{"romaji":"Joou Heika no Petite Angie"}},{"id":10554,"title":{"romaji":"Yakyuukyou no Uta"}},{"id":7117,"title":{"romaji":"Pika Don"}},{"id":16554,"title":{"romaji":"Dallyeola Majing-ga-X"}},{"id":16812,"title":{"romaji":"77 Danui Bimil"}},{"id":16814,"title":{"romaji":"Son Okong-gwa Byeoldeul-ui Jeonjaeng"}},{"id":19555,"title":{"romaji":"Ttoli Janggun"}},{"id":102667,"title":{"romaji":"Motion Lumine"}}]}}}'

# %%
import numpy as np
with open('matrix.npy', 'rb') as f:
    a = np.load(f)
a
# Out:
# array([[4.3462e+04, 1.4160e+04, 1.3841e+04, ..., 6.7210e+03, 6.9620e+03,
#         6.3230e+03],
#        [1.4160e+04, 6.2357e+04, 0.0000e+00, ..., 1.8888e+04, 6.9600e+03,
#         1.5239e+04],
#        [1.3841e+04, 0.0000e+00, 9.5694e+04, ..., 1.9807e+04, 2.0000e+00,
#         2.0000e+00],
#        ...,
#        [6.7210e+03, 1.8888e+04, 1.9807e+04, ..., 7.5438e+04, 2.2704e+04,
#         6.6390e+03],
#        [6.9620e+03, 6.9600e+03, 2.0000e+00, ..., 2.2704e+04, 8.5140e+04,
#         6.8770e+03],
#        [6.3230e+03, 1.5239e+04, 2.0000e+00, ..., 6.6390e+03, 6.8770e+03,
#         6.7298e+04]])
